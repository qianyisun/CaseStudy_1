# %% [markdown]
# #### Load package

# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np

# %% [markdown]
# #### Load data

# %%
SNFs = pd.read_excel(r'D:\fall2020\case study\case study 1\CaseStudy_1\Data\SNFs.xlsx')

# %%
Episodes = pd.read_excel(r'D:\fall2020\case study\case study 1\CaseStudy_1\Data\Episodes.xlsx')

# %% [markdown]
# #### Data first look

# %%
SNFs.head()
# Out:
#                                         ProviderName  PID  \
# 0                               648 Medical Squadron    1
# 1          Abilene Nursing and Rehabilitation Center    2
# 2                    Abilene Regional Medical Center    3
# 3  Abilene Regional Medical Center Skilled Nursin...    4
# 4                             Absolutely Angels, Inc    5
#
#             ProviderPracticeAddress1 ProviderPracticeAddress2  \
# 0                  8006 CHENNAULT RD                    STE 1
# 1                  2630 OLD ANSON RD                      NaN
# 2                 6250 US HIGHWAY 83                      NaN
# 3  6250 HIGHWAY 83 84 AT ANTILLEY RD                      NaN
# 4                936 E PRODUCTION DR                      NaN
#
#   ProviderPracticeCity ProviderPracticeStateCode  ProviderPracticeZipCode  \
# 0     BROOKS CITY BASE                        TX                    78235
# 1              ABILENE                        TX                    79603
# 2              ABILENE                        TX                    79606
# 3              ABILENE                        TX                    79606
# 4          PILOT POINT                        TX                    76258
#
#    County
# 0   Bexar
# 1  Taylor
# 2  Taylor
# 3  Taylor
# 4  Denton

# %%
# count the number of unique values for each column in SNFs
SNFs.nunique()
# Out:
# ProviderName                 1797
# PID                          1813
# ProviderPracticeAddress1     1728
# ProviderPracticeAddress2       16
# ProviderPracticeCity          507
# ProviderPracticeStateCode       1
# ProviderPracticeZipCode       782
# County                        235
# dtype: int64

# %%
SNFs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1813 entries, 0 to 1812
# Data columns (total 8 columns):
# ProviderName                 1813 non-null object
# PID                          1813 non-null int64
# ProviderPracticeAddress1     1813 non-null object
# ProviderPracticeAddress2     17 non-null object
# ProviderPracticeCity         1813 non-null object
# ProviderPracticeStateCode    1813 non-null object
# ProviderPracticeZipCode      1813 non-null int64
# County                       1674 non-null object
# dtypes: int64(2), object(6)
# memory usage: 113.4+ KB

# %%
# percent of missingness for all columns in SNFs
count = SNFs.isna().sum()
missingness = (pd.concat([count.rename('missing_count'),
                     count.div(len(SNFs))
                          .rename('missing_ratio')],axis = 1)
             .loc[count.ne(0)])
missingness.sort_values(by = ['missing_ratio'], ascending=False)
# Out:
#                           missing_count  missing_ratio
# ProviderPracticeAddress2           1796       0.990623
# County                              139       0.076669

# %% [markdown]
# Suggest to use city instead of county since there is no missing values for city variable

# %% [markdown]
# #### Align SNFs with Episodes

# %%
# merge SNFs with Episodes and only keep SNF that has patient data in Episodes
# Reasons to do this: simplier question and, for the SNFs that do not have any patient record,
# no way to confirm that they need CCs and they need how many CCs.
common_epi_snf = SNFs.merge(Episodes, on=["PID"])
SNFs_no_episodes = SNFs[~SNFs.PID.isin(common_epi_snf.PID)]

# %%
SNFs_no_episodes.head()
# Out:
#                                         ProviderName  PID  \
# 0                               648 Medical Squadron    1
# 1          Abilene Nursing and Rehabilitation Center    2
# 2                    Abilene Regional Medical Center    3
# 3  Abilene Regional Medical Center Skilled Nursin...    4
# 4                             Absolutely Angels, Inc    5
#
#             ProviderPracticeAddress1 ProviderPracticeAddress2  \
# 0                  8006 CHENNAULT RD                    STE 1
# 1                  2630 OLD ANSON RD                      NaN
# 2                 6250 US HIGHWAY 83                      NaN
# 3  6250 HIGHWAY 83 84 AT ANTILLEY RD                      NaN
# 4                936 E PRODUCTION DR                      NaN
#
#   ProviderPracticeCity ProviderPracticeStateCode  ProviderPracticeZipCode  \
# 0     BROOKS CITY BASE                        TX                    78235
# 1              ABILENE                        TX                    79603
# 2              ABILENE                        TX                    79606
# 3              ABILENE                        TX                    79606
# 4          PILOT POINT                        TX                    76258
#
#    County
# 0   Bexar
# 1  Taylor
# 2  Taylor
# 3  Taylor
# 4  Denton

# %%
common_snf = SNFs.merge(SNFs_no_episodes, on=["PID"])
SNFs_with_episodes = SNFs[~SNFs.PID.isin(common_snf.PID)]

# %%
SNFs_with_episodes.head()
# Out:
#                                          ProviderName  PID  \
# 5                            Accel at College Station    6
# 7                                Accel at Willow Bend    8
# 8                                  Adora Midtown Park    9
# 9                        Advance Healthcare Solutions   10
# 10  Advanced Health and Rehabilitation Center of G...   11
#
#     ProviderPracticeAddress1 ProviderPracticeAddress2 ProviderPracticeCity  \
# 5           1500 MEDICAL AVE                      NaN      COLLEGE STATION
# 7   2620 COMMUNICATIONS PKWY                      NaN                PLANO
# 8             8130 MEADOW RD                      NaN               DALLAS
# 9             4863 KEMP BLVD                      NaN        WICHITA FALLS
# 10           1201 COLONEL DR                      NaN              GARLAND
#
#    ProviderPracticeStateCode  ProviderPracticeZipCode   County
# 5                         TX                    77845      NaN
# 7                         TX                    75093   Collin
# 8                         TX                    75231      NaN
# 9                         TX                    76308  Wichita
# 10                        TX                    75043   Dallas

# %%
SNFs_with_episodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1248 entries, 5 to 1812
# Data columns (total 8 columns):
# ProviderName                 1248 non-null object
# PID                          1248 non-null int64
# ProviderPracticeAddress1     1248 non-null object
# ProviderPracticeAddress2     3 non-null object
# ProviderPracticeCity         1248 non-null object
# ProviderPracticeStateCode    1248 non-null object
# ProviderPracticeZipCode      1248 non-null int64
# County                       1186 non-null object
# dtypes: int64(2), object(6)
# memory usage: 87.8+ KB

# %% [markdown]
# One problem here is the repeating observations, and there are two conditions:
#
# 1. Same SNF with two observations, one has name in upper case, one has name in lower case
# 2. Same SNF with similar name (has confirmed with the professor, and he said observations with the same location are actually representing the same SNF)
#
# So I took out the repeating rows be the following steps.

# %%
# Aligh with unique address and city
repeat = SNFs_with_episodes[SNFs_with_episodes.duplicated(subset=['ProviderPracticeAddress1', 'ProviderPracticeCity'],keep=False)].sort_values(by ='ProviderPracticeAddress1')
repeat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 560 to 11
# Data columns (total 8 columns):
# ProviderName                 26 non-null object
# PID                          26 non-null int64
# ProviderPracticeAddress1     26 non-null object
# ProviderPracticeAddress2     0 non-null object
# ProviderPracticeCity         26 non-null object
# ProviderPracticeStateCode    26 non-null object
# ProviderPracticeZipCode      26 non-null int64
# County                       17 non-null object
# dtypes: int64(2), object(6)
# memory usage: 1.8+ KB

# %%
common_both = SNFs_with_episodes.merge(repeat, on=["PID"])
SNFs_unique = SNFs_with_episodes[~SNFs_with_episodes.PID.isin(common_both.PID)]

# %%
SNFs_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1222 entries, 5 to 1812
# Data columns (total 8 columns):
# ProviderName                 1222 non-null object
# PID                          1222 non-null int64
# ProviderPracticeAddress1     1222 non-null object
# ProviderPracticeAddress2     3 non-null object
# ProviderPracticeCity         1222 non-null object
# ProviderPracticeStateCode    1222 non-null object
# ProviderPracticeZipCode      1222 non-null int64
# County                       1169 non-null object
# dtypes: int64(2), object(6)
# memory usage: 85.9+ KB

# %%
repeat_for_join = repeat.groupby(['ProviderPracticeAddress1','County'], as_index = False).first()

# %%
repeat_for_join
# Out:
#    ProviderPracticeAddress1    County  \
# 0             101 POSEY AVE    Bosque
# 1        11106 CHRISTUS HLS     Bexar
# 2       1154 E HAWKINS PKWY     Gregg
# 3        1302 NOTTINGHAM ST    Walker
# 4          14100 KARISSA CT    Harris
# 5             14949 MESA DR    Harris
# 6              1621 COIT RD    Collin
# 7          2000 BEAUMONT RD    Harris
# 8         2625 BELT LINE RD    Dallas
# 9     2700 S HENDERSON BLVD     Gregg
# 10      3505 S BUCKNER BLVD    Dallas
# 11            707 ROLAND ST  Hansford
# 12        8221 PALISADES DR     Bexar
#
#                                          ProviderName   PID  \
# 0          Goodall Witcher Nursing Facility Swing Bed   561
# 1                         Windemere at Westover Hills  1771
# 2                           Treviso Transitional Care  1631
# 3                          Focused Care At Huntsville   485
# 4               Bridgecrest Rehabiliation Suites, LLC   146
# 5     Fall Creek Rehabilitation And Healthcare Center   464
# 6                                   Landmark At Plano   802
# 7                             Focused Care At Baytown   478
# 8   Legend Oaks Healthcare and Rehabilitation Garland   836
# 9                              Arbor Grace Of Kilgore    38
# 10                                Brentwood Place III   138
# 11                                     Hansford Manor   613
# 12                      Advanced Rehab and Healthcare    12
#
#     ProviderPracticeAddress2 ProviderPracticeCity ProviderPracticeStateCode  \
# 0                        NaN              CLIFTON                        TX
# 1                        NaN          SAN ANTONIO                        TX
# 2                        NaN             LONGVIEW                        TX
# 3                        NaN           HUNTSVILLE                        TX
# 4                        NaN              HOUSTON                        TX
# 5                        NaN               HUMBLE                        TX
# 6                        NaN                PLANO                        TX
# 7                        NaN              BAYTOWN                        TX
# 8                        NaN              GARLAND                        TX
# 9                        NaN              KILGORE                        TX
# 10                       NaN               DALLAS                        TX
# 11                       NaN             SPEARMAN                        TX
# 12                       NaN             LIVE OAK                        TX
#
#     ProviderPracticeZipCode
# 0                     76634
# 1                     78251
# 2                     75605
# 3                     77340
# 4                     77049
# 5                     77396
# 6                     75075
# 7                     77520
# 8                     75044
# 9                     75662
# 10                    75227
# 11                    79081
# 12                    78233

# %%
frames = [SNFs_unique, repeat_for_join]
SNFs_fixed = pd.concat(frames, sort = False)

# %%
# SNFs after the fixing process
# Ready to use
SNFs_fixed.nunique()
# Out:
# ProviderName                 1229
# PID                          1235
# ProviderPracticeAddress1     1233
# ProviderPracticeAddress2        3
# ProviderPracticeCity          433
# ProviderPracticeStateCode       1
# ProviderPracticeZipCode       664
# County                        212
# dtype: int64

# %% [markdown]
# One thought here:
#
# Counts of providers for county have relative higher values, which means for the result, when assigning CCs, the counts would be higher for CCs if we go with county

# %%
SNFs_fixed.groupby(["ProviderPracticeCity"]).ProviderName.count().sort_values(ascending=False)
# Out:
# ProviderPracticeCity
# HOUSTON                 70
# SAN ANTONIO             61
# FORT WORTH              38
# DALLAS                  35
# AUSTIN                  26
# EL PASO                 21
# CORPUS CHRISTI          16
# TYLER                   12
# LUBBOCK                 11
# AMARILLO                11
# TEMPLE                  11
# WACO                    11
# ARLINGTON               10
# LONGVIEW                 9
# PLANO                    9
# ABILENE                  9
# MCALLEN                  9
# WICHITA FALLS            9
# MESQUITE                 8
# BEAUMONT                 8
# RICHARDSON               7
# WEATHERFORD              7
# PASADENA                 7
# KATY                     7
# DENTON                   7
# KERRVILLE                7
# SAN ANGELO               6
# TEXAS CITY               6
# TEXARKANA                6
# BROWNSVILLE              6
#                         ..
# DEVINE                   1
# ROBERT LEE               1
# FORNEY                   1
# PHARR                    1
# FRANKLIN                 1
# PERRYTON                 1
# GROVETON                 1
# MOULTON                  1
# MOUNT VERNON             1
# GRANDVIEW                1
# MUENSTER                 1
# NEEDVILLE                1
# NEWTON                   1
# NOCONA                   1
# GOLIAD                   1
# GOLDTHWAITE              1
# NORTH RICHLAND HILLS     1
# GLADEWATER               1
# OLNEY                    1
# OLTON                    1
# ORANGE                   1
# GEORGE WEST              1
# OVERTON                  1
# GARRISON                 1
# PALACIOS                 1
# GANADO                   1
# PECOS                    1
# FRIONA                   1
# FRIENDSWOOD              1
# ZAPATA                   1
# Name: ProviderName, Length: 433, dtype: int64

# %%
SNFs_fixed.groupby(["County"]).ProviderName.count().sort_values(ascending=False)
# Out:
# County
# Harris         103
# Dallas          76
# Tarrant         70
# Bexar           60
# Travis          28
# Collin          22
# Hidalgo         20
# Nueces          17
# Denton          17
# Bell            17
# El Paso         17
# McLennan        15
# Fort Bend       14
# Wichita         14
# Brazoria        13
# Smith           13
# Lubbock         12
# Jefferson       12
# Williamson      12
# Galveston       12
# Gregg           12
# Cameron         11
# Grayson         10
# Taylor          10
# Cherokee         9
# Montgomery       9
# Ellis            9
# Lavaca           8
# Potter           8
# Johnson          8
#               ...
# Leon             1
# Live Oak         1
# Rains            1
# Lynn             1
# Martin           1
# McCulloch        1
# Menard           1
# Mills            1
# Mitchell         1
# Morris           1
# Newton           1
# Kimble           1
# Jim Hogg         1
# Jack             1
# Gaines           1
# Dallam           1
# Delta            1
# Upton            1
# Duval            1
# Foard            1
# Franklin         1
# Stonewall        1
# Sabine           1
# Garza            1
# Goliad           1
# Sterling         1
# Hall             1
# Hansford         1
# San Jacinto      1
# Zapata           1
# Name: ProviderName, Length: 212, dtype: int64

# %%
SNFs_fixed.to_csv('SNFs.csv', index=False)

# %% [markdown]
# #### Episodes

# %%
Episodes.nunique()
# Out:
# PID               1248
# EpisodeID        40998
# ContractType         2
# AdmitDate           12
# DischargeDate      534
# dtype: int64

# %%
Episodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40998 entries, 0 to 40997
# Data columns (total 5 columns):
# PID              40998 non-null int64
# EpisodeID        40998 non-null int64
# ContractType     40998 non-null object
# AdmitDate        40998 non-null object
# DischargeDate    39849 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# Replacing wrong PID with the correct one

# %%
Episodes['PID'] = Episodes['PID'].replace([560, 1770, 1632, 484, 147, 463, 804, 474, 837, 757, 135, 612, 16],[561, 1771, 1631, 485, 146, 464, 802, 478, 836, 38, 138, 613, 12])

# %%
# convert to datetime type
Episodes['AdmitDate']= pd.to_datetime(Episodes['AdmitDate'])
Episodes['DischargeDate']= pd.to_datetime(Episodes['DischargeDate'])

# %%
count = Episodes.isna().sum()
missingness = (pd.concat([count.rename('missing_count'),
                     count.div(len(Episodes))
                          .rename('missing_ratio')],axis = 1)
             .loc[count.ne(0)])
missingness.sort_values(by = ['missing_ratio'], ascending=False)
# Out:
#                missing_count  missing_ratio
# DischargeDate           1149       0.028026

# %% [markdown]
# Taking out rows that doesn't have a discharge date

# %%
Episodes = Episodes.dropna(axis=0, subset=['DischargeDate'])

# %% [markdown]
# Having a new column storing the time difference

# %%
# have a new column store time difference
Episodes['time_diff'] = Episodes['DischargeDate'] - Episodes['AdmitDate']

# %%
Episodes = pd.DataFrame(Episodes)

# %%
Episodes
# Out:
#         PID  EpisodeID ContractType  AdmitDate DischargeDate time_diff
# 0       530          1          CT1 2019-12-01    2020-01-30   60 days
# 2      1107          3          CT2 2019-12-01    2019-12-07    6 days
# 3      1107          4          CT2 2019-12-01    2019-12-02    1 days
# 5       842          6          CT2 2019-12-01    2019-12-04    3 days
# 6      1178          7          CT2 2019-12-01    2019-12-17   16 days
# 7       857          8          CT1 2019-12-01    2019-12-23   22 days
# 8      1553          9          CT1 2019-12-01    2019-12-28   27 days
# 9      1187         10          CT1 2019-12-01    2019-12-02    1 days
# 10      268         11          CT1 2019-12-01    2020-01-21   51 days
# 11     1516         12          CT2 2019-12-01    2020-01-03   33 days
# 12     1415         13          CT2 2019-12-01    2019-12-09    8 days
# 14     1520         15          CT1 2019-12-01    2019-12-21   20 days
# 15      520         16          CT1 2019-12-01    2020-04-10  131 days
# 16      168         17          CT2 2019-12-01    2019-12-10    9 days
# 18     1762         19          CT1 2019-12-01    2020-01-04   34 days
# 19      139         20          CT1 2019-12-01    2020-01-08   38 days
# 20      549         21          CT1 2019-12-01    2019-12-17   16 days
# 21     1047         22          CT1 2019-12-01    2019-12-11   10 days
# 22     1533         23          CT1 2019-12-01    2019-12-04    3 days
# 23     1654         24          CT2 2019-12-01    2019-12-14   13 days
# 24     1564         25          CT2 2019-12-01    2019-12-16   15 days
# 25     1316         26          CT1 2019-12-01    2020-02-25   86 days
# 26     1562         27          CT1 2019-12-01    2020-02-16   77 days
# 27     1801         28          CT1 2019-12-01    2020-01-13   43 days
# 28      334         29          CT1 2019-12-01    2020-01-23   53 days
# 29     1616         30          CT1 2019-12-01    2019-12-24   23 days
# 30     1775         31          CT1 2019-12-01    2020-01-17   47 days
# 31     1515         32          CT2 2019-12-01    2019-12-10    9 days
# 32      575         33          CT1 2019-12-01    2020-01-03   33 days
# 33      480         34          CT2 2019-12-01    2019-12-13   12 days
# ...     ...        ...          ...        ...           ...       ...
# 40968   527      56788          CT1 2019-01-01    2019-01-21   20 days
# 40969   752      56789          CT1 2019-01-01    2019-01-11   10 days
# 40970   244      56790          CT1 2019-01-01    2019-01-20   19 days
# 40971  1707      56791          CT1 2019-01-01    2019-01-31   30 days
# 40972   161      56792          CT1 2019-01-01    2019-01-24   23 days
# 40973  1256      56793          CT1 2019-01-01    2019-01-14   13 days
# 40974  1301      56794          CT1 2019-01-01    2019-01-06    5 days
# 40975   683      56795          CT1 2019-01-01    2019-01-24   23 days
# 40976   667      56796          CT1 2019-01-01    2019-01-21   20 days
# 40977  1292      56797          CT1 2019-01-01    2019-01-18   17 days
# 40978  1724      56798          CT1 2019-01-01    2019-01-09    8 days
# 40979   140      56799          CT1 2019-01-01    2019-01-04    3 days
# 40980  1795      56800          CT1 2019-01-01    2019-04-02   91 days
# 40981   551      56801          CT1 2019-01-01    2019-02-27   57 days
# 40982  1177      56802          CT1 2019-01-01    2019-01-16   15 days
# 40983  1807      56803          CT1 2019-01-01    2019-01-07    6 days
# 40984  1807      56804          CT1 2019-01-01    2019-01-21   20 days
# 40985     9      56805          CT1 2019-01-01    2019-01-16   15 days
# 40986  1071      56806          CT1 2019-01-01    2019-01-14   13 days
# 40987   429      56807          CT1 2019-01-01    2019-01-18   17 days
# 40988    22      56808          CT1 2019-01-01    2019-01-15   14 days
# 40989   148      56809          CT1 2019-01-01    2019-01-08    7 days
# 40990  1570      56810          CT1 2019-01-01    2019-05-13  132 days
# 40991   382      56811          CT1 2019-01-01    2019-02-04   34 days
# 40992  1795      56812          CT1 2019-01-01    2019-04-02   91 days
# 40993  1771      56813          CT1 2019-01-01    2019-01-15   14 days
# 40994  1177      56814          CT1 2019-01-01    2019-01-14   13 days
# 40995  1187      56815          CT1 2019-01-01    2019-02-07   37 days
# 40996  1771      56816          CT1 2019-01-01    2019-01-18   17 days
# 40997  1807      56817          CT1 2019-01-01    2019-01-18   17 days
#
# [39849 rows x 6 columns]

# %%
Episodes.min()
# Out:
# PID                                6
# EpisodeID                          1
# ContractType                     CT1
# AdmitDate        2019-01-01 00:00:00
# DischargeDate    2018-11-01 00:00:00
# time_diff         -61 days +00:00:00
# dtype: object

# %%
Episodes = Episodes[Episodes['time_diff'].dt.days >= 0]

# %%
Episodes = Episodes.drop(['time_diff'], axis = 1)

# %%
Episodes
# Out:
#         PID  EpisodeID ContractType  AdmitDate DischargeDate
# 0       530          1          CT1 2019-12-01    2020-01-30
# 2      1107          3          CT2 2019-12-01    2019-12-07
# 3      1107          4          CT2 2019-12-01    2019-12-02
# 5       842          6          CT2 2019-12-01    2019-12-04
# 6      1178          7          CT2 2019-12-01    2019-12-17
# 7       857          8          CT1 2019-12-01    2019-12-23
# 8      1553          9          CT1 2019-12-01    2019-12-28
# 9      1187         10          CT1 2019-12-01    2019-12-02
# 10      268         11          CT1 2019-12-01    2020-01-21
# 11     1516         12          CT2 2019-12-01    2020-01-03
# 12     1415         13          CT2 2019-12-01    2019-12-09
# 14     1520         15          CT1 2019-12-01    2019-12-21
# 15      520         16          CT1 2019-12-01    2020-04-10
# 16      168         17          CT2 2019-12-01    2019-12-10
# 18     1762         19          CT1 2019-12-01    2020-01-04
# 19      139         20          CT1 2019-12-01    2020-01-08
# 20      549         21          CT1 2019-12-01    2019-12-17
# 21     1047         22          CT1 2019-12-01    2019-12-11
# 22     1533         23          CT1 2019-12-01    2019-12-04
# 23     1654         24          CT2 2019-12-01    2019-12-14
# 24     1564         25          CT2 2019-12-01    2019-12-16
# 25     1316         26          CT1 2019-12-01    2020-02-25
# 26     1562         27          CT1 2019-12-01    2020-02-16
# 27     1801         28          CT1 2019-12-01    2020-01-13
# 28      334         29          CT1 2019-12-01    2020-01-23
# 29     1616         30          CT1 2019-12-01    2019-12-24
# 30     1775         31          CT1 2019-12-01    2020-01-17
# 31     1515         32          CT2 2019-12-01    2019-12-10
# 32      575         33          CT1 2019-12-01    2020-01-03
# 33      480         34          CT2 2019-12-01    2019-12-13
# ...     ...        ...          ...        ...           ...
# 40968   527      56788          CT1 2019-01-01    2019-01-21
# 40969   752      56789          CT1 2019-01-01    2019-01-11
# 40970   244      56790          CT1 2019-01-01    2019-01-20
# 40971  1707      56791          CT1 2019-01-01    2019-01-31
# 40972   161      56792          CT1 2019-01-01    2019-01-24
# 40973  1256      56793          CT1 2019-01-01    2019-01-14
# 40974  1301      56794          CT1 2019-01-01    2019-01-06
# 40975   683      56795          CT1 2019-01-01    2019-01-24
# 40976   667      56796          CT1 2019-01-01    2019-01-21
# 40977  1292      56797          CT1 2019-01-01    2019-01-18
# 40978  1724      56798          CT1 2019-01-01    2019-01-09
# 40979   140      56799          CT1 2019-01-01    2019-01-04
# 40980  1795      56800          CT1 2019-01-01    2019-04-02
# 40981   551      56801          CT1 2019-01-01    2019-02-27
# 40982  1177      56802          CT1 2019-01-01    2019-01-16
# 40983  1807      56803          CT1 2019-01-01    2019-01-07
# 40984  1807      56804          CT1 2019-01-01    2019-01-21
# 40985     9      56805          CT1 2019-01-01    2019-01-16
# 40986  1071      56806          CT1 2019-01-01    2019-01-14
# 40987   429      56807          CT1 2019-01-01    2019-01-18
# 40988    22      56808          CT1 2019-01-01    2019-01-15
# 40989   148      56809          CT1 2019-01-01    2019-01-08
# 40990  1570      56810          CT1 2019-01-01    2019-05-13
# 40991   382      56811          CT1 2019-01-01    2019-02-04
# 40992  1795      56812          CT1 2019-01-01    2019-04-02
# 40993  1771      56813          CT1 2019-01-01    2019-01-15
# 40994  1177      56814          CT1 2019-01-01    2019-01-14
# 40995  1187      56815          CT1 2019-01-01    2019-02-07
# 40996  1771      56816          CT1 2019-01-01    2019-01-18
# 40997  1807      56817          CT1 2019-01-01    2019-01-18
#
# [39845 rows x 5 columns]

# %%
Episodes.to_csv('Episodes.csv', index=False)

# %% [markdown]
# #### EDA on Contract

# %%
#Total number of patients based on PID and Contract type
Episodes.groupby(["PID", "ContractType"]).ContractType.count()
# Out:
# PID   ContractType
# 6     CT1               1
#       CT2              65
# 8     CT1              25
#       CT2              82
# 9     CT1              61
#       CT2              26
# 10    CT2               4
# 11    CT1               2
#       CT2              23
# 12    CT1              13
#       CT2              19
# 13    CT1               1
#       CT2              25
# 14    CT2              52
# 15    CT2              37
# 17    CT1              43
#       CT2              72
# 18    CT2              37
# 19    CT2              33
# 20    CT1              12
#       CT2              13
# 21    CT1               1
#       CT2               5
# 22    CT1              87
#       CT2              12
# 23    CT1              18
#       CT2               8
# 25    CT1              56
#       CT2              46
# 27    CT1               6
#                      ...
# 1788  CT2               7
# 1789  CT2               5
# 1790  CT2               1
# 1791  CT1               1
#       CT2               1
# 1792  CT2               1
# 1793  CT1               3
#       CT2               9
# 1794  CT2              19
# 1795  CT1              12
#       CT2               3
# 1796  CT1               6
# 1797  CT1               1
#       CT2              29
# 1800  CT1               1
# 1801  CT1              51
# 1802  CT2              19
# 1803  CT1               6
#       CT2             128
# 1804  CT1               2
#       CT2               6
# 1805  CT2               9
# 1806  CT2              22
# 1807  CT1              19
#       CT2              27
# 1808  CT2              42
# 1810  CT2               2
# 1811  CT2               6
# 1812  CT2               5
# 1813  CT2               5
# Name: ContractType, Length: 1914, dtype: int64

# %%
#Total days spent based on PID and Contract type
Episodes.groupby(["PID", "ContractType"])['time_diff'].agg('sum')
# Out:
# PID   ContractType
# 6     CT1               7 days
#       CT2            1062 days
# 8     CT1            1047 days
#       CT2            1287 days
# 9     CT1            1653 days
#       CT2             419 days
# 10    CT2              56 days
# 11    CT1             168 days
#       CT2             367 days
# 12    CT1             324 days
#       CT2             264 days
# 13    CT1              91 days
#       CT2             353 days
# 14    CT2             895 days
# 15    CT2             553 days
# 17    CT1             679 days
#       CT2            1029 days
# 18    CT2             609 days
# 19    CT2             481 days
# 20    CT1             267 days
#       CT2             271 days
# 21    CT1               0 days
#       CT2              69 days
# 22    CT1            2564 days
#       CT2             192 days
# 23    CT1             216 days
#       CT2              92 days
# 25    CT1            1260 days
#       CT2             711 days
# 27    CT1             150 days
#                         ...
# 1788  CT2             180 days
# 1789  CT2              81 days
# 1790  CT2              17 days
# 1791  CT1              90 days
#       CT2              14 days
# 1792  CT2              15 days
# 1793  CT1             186 days
#       CT2             170 days
# 1794  CT2             329 days
# 1795  CT1            1092 days
#       CT2              39 days
# 1796  CT1              84 days
# 1797  CT1              53 days
#       CT2             488 days
# 1800  CT1               6 days
# 1801  CT1            1982 days
# 1802  CT2             253 days
# 1803  CT1             295 days
#       CT2            2047 days
# 1804  CT1             138 days
#       CT2             140 days
# 1805  CT2             123 days
# 1806  CT2             353 days
# 1807  CT1             320 days
#       CT2             428 days
# 1808  CT2             736 days
# 1810  CT2              15 days
# 1811  CT2              91 days
# 1812  CT2              85 days
# 1813  CT2              78 days
# Name: time_diff, Length: 1914, dtype: timedelta64[ns]

# %% [markdown]
# Start from here: may be find some linear relationship based on this following chart？

# %%
# How many patients go to the same SNFs on the same dayunder different contract type
Episodes.groupby(["PID", "AdmitDate", "ContractType"]).ContractType.count()
# Out:
# PID   AdmitDate   ContractType
# 6     2019-01-01  CT2             11
#       2019-02-01  CT2              5
#       2019-03-01  CT2              7
#       2019-04-01  CT1              1
#                   CT2              4
#       2019-05-01  CT2              4
#       2019-06-01  CT2              3
#       2019-07-01  CT2              2
#       2019-08-01  CT2              5
#       2019-09-01  CT2              6
#       2019-10-01  CT2              4
#       2019-11-01  CT2              3
#       2019-12-01  CT2             11
# 8     2019-01-01  CT1              1
#                   CT2             19
#       2019-02-01  CT1              2
#                   CT2              8
#       2019-03-01  CT1              2
#                   CT2              8
#       2019-04-01  CT1              1
#                   CT2              6
#       2019-05-01  CT1              3
#                   CT2              8
#       2019-06-01  CT1              1
#                   CT2             13
#       2019-07-01  CT1              1
#                   CT2              8
#       2019-08-01  CT2              5
#       2019-09-01  CT1              1
#                   CT2              5
#                                   ..
# 1807  2019-09-01  CT2              1
#       2019-10-01  CT2              1
#       2019-11-01  CT1              3
#                   CT2              1
# 1808  2019-01-01  CT2              4
#       2019-02-01  CT2              2
#       2019-03-01  CT2              4
#       2019-04-01  CT2              1
#       2019-05-01  CT2              2
#       2019-06-01  CT2              7
#       2019-07-01  CT2              2
#       2019-08-01  CT2              4
#       2019-09-01  CT2              5
#       2019-10-01  CT2              3
#       2019-11-01  CT2              5
#       2019-12-01  CT2              3
# 1810  2019-06-01  CT2              2
# 1811  2019-02-01  CT2              1
#       2019-03-01  CT2              1
#       2019-06-01  CT2              1
#       2019-07-01  CT2              1
#       2019-10-01  CT2              1
#       2019-11-01  CT2              1
# 1812  2019-02-01  CT2              3
#       2019-04-01  CT2              1
#       2019-07-01  CT2              1
# 1813  2019-02-01  CT2              1
#       2019-06-01  CT2              1
#       2019-11-01  CT2              1
#       2019-12-01  CT2              2
# Name: ContractType, Length: 12759, dtype: int64

# %% [markdown]
# More questions:
#
# Did not figure out how to calculate the estimate time for the two types of contract.
#
# After figuring this out, we could add it as a feature?
