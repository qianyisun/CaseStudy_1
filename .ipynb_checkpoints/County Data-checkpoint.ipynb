# %%
import pandas as pd 
import numpy as np
snf = pd.read_csv("SNFs.csv")
episodes = pd.read_csv("episodes_dur.csv")

# %%
snf
# Out:
#                                            ProviderName  PID  \
# 0                              Accel at College Station    6
# 1                                  Accel at Willow Bend    8
# 2                                    Adora Midtown Park    9
# 3                          Advance Healthcare Solutions   10
# 4     Advanced Health and Rehabilitation Center of G...   11
# ...                                                 ...  ...
# 1230  Legend Oaks Healthcare and Rehabilitation Garland  836
# 1231                             Arbor Grace Of Kilgore   38
# 1232                                Brentwood Place III  138
# 1233                                     Hansford Manor  613
# 1234                      Advanced Rehab and Healthcare   12
#
#       ProviderPracticeAddress1 ProviderPracticeAddress2 ProviderPracticeCity  \
# 0             1500 MEDICAL AVE                      NaN      COLLEGE STATION
# ...

# %%
episodes
# Out:
#        Unnamed: 0   PID  EpisodeID ContractType  duration
# 0               0   530          1          CT1      60.0
# 1               1  1107          3          CT2       6.0
# 2               2  1107          4          CT2       1.0
# 3               3   842          6          CT2       3.0
# 4               4  1178          7          CT2      16.0
# ...           ...   ...        ...          ...       ...
# 39844       39844  1771      56813          CT1      14.0
# 39845       39845  1177      56814          CT1      13.0
# 39846       39846  1187      56815          CT1      37.0
# 39847       39847  1771      56816          CT1      17.0
# 39848       39848  1807      56817          CT1      17.0
#
# [39849 rows x 5 columns]

# %%
num_patients = episodes.groupby(['PID']).size()

# %%
num_patients = num_patients.to_frame().reset_index()
num_patients
# Out:
#        PID    0
# 0        6   66
# 1        8  107
# 2        9   87
# 3       10    4
# 4       11   25
# ...    ...  ...
# 1226  1808   42
# 1227  1810    2
# 1228  1811    6
# 1229  1812    5
# 1230  1813    5
#
# [1231 rows x 2 columns]

# %%
num_patients.columns = ['PID', '#patients']

# %%
num_patients
# Out:
#        PID  #patients
# 0        6         66
# 1        8        107
# 2        9         87
# 3       10          4
# 4       11         25
# ...    ...        ...
# 1226  1808         42
# 1227  1810          2
# 1228  1811          6
# 1229  1812          5
# 1230  1813          5
#
# [1231 rows x 2 columns]

# %%
snf = snf.merge(num_patients, on = 'PID')

# %%
snf = snf[['PID', 'County', '#patients']]

# %%
snf
# Out:
#       PID    County  #patients
# 0       6       NaN         66
# 1       8    Collin        107
# 2       9       NaN         87
# 3      10   Wichita          4
# 4      11    Dallas         25
# ...   ...       ...        ...
# 1226  836    Dallas         31
# 1227   38     Gregg         11
# 1228  138    Dallas         10
# 1229  613  Hansford          3
# 1230   12     Bexar         32
#
# [1231 rows x 3 columns]

# %%
pid_per_county = snf.groupby(['County']).size()

# %%
pid_per_county = pid_per_county.to_frame().reset_index()
pid_per_county.columns = ['County', '#SNFs']

# %%
patientsbycounty = snf.groupby(['County']).agg('sum').reset_index()

# %%
patientsbycounty = patientsbycounty.drop(['PID'], axis = 1)

# %%
county_level_data = pid_per_county.merge(patientsbycounty, on = 'County')

# %%
county_level_data
# Out:
#        County  #SNFs  #patients
# 0    Anderson      5         87
# 1     Andrews      1          1
# 2    Angelina      8        283
# 3     Aransas      2         37
# 4      Archer      1          1
# ..        ...    ...        ...
# 207      Wise      3        128
# 208      Wood      7         59
# 209    Yoakum      2          8
# 210     Young      4         43
# 211    Zapata      1          1
#
# [212 rows x 3 columns]

# %%
county_level_data.to_csv('County_Data.csv', index = False)
